# %%
from google.colab import drive
drive.mount('/content/drive')
# !/opt/bin/nvidia-smi
# !cat /etc/issue

# %%
# !gcc --version
# !g++ --version
# !whereis gcc-5

# !sudo apt-get install gcc-5
!--install <link> <name> <path> <priority>
# !sudo update-alternatives --install /usr/bin/gcc gcc /usr/bin/gcc-5 100

# !sudo apt autoremove
# !sudo apt-get update gcc-5
# !sudo apt-get install g++-5

# !gcc --version
# !g++ --version
# !whereis gcc-5

# %%
# !sudo apt autoremove
# !sudo apt-get install python3.7-dev
import os
os.chdir("/content/drive/MyDrive/votenet/votenet-main/pointnet2")
# !python setup.py install

# %%
# !pip install matplotlib
# !pip install opencv-python
# !pip install plyfile
# !pip install 'trimesh>=2.35.39,<2.35.40'
# !pip install 'networkx>=2.2,<2.3'

# %%
# !python /content/drive/MyDrive/votenet/votenet-main/models/votenet.py
